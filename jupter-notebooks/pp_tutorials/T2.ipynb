# %%
import pandapower as pp
import pandapower.networks as nw

# %%
net = nw.mv_oberrhein()
#print(net.bus)
pp.runpp(net)
# Out:
# /home/marco/Desktop/ATOM/optimization/.venv/lib/python3.10/site-packages/pandapower/networks/mv_oberrhein.py:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-2, -3]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   net.trafo.loc[hv_trafos, "tap_pos"] = [-2, -3]

# %%
net.res_bus.head()
# Out:
#       vm_pu   va_degree  p_mw    q_mvar
# 0  1.009473 -156.778921  0.24  0.048734
# 1  1.009354 -156.783526  0.15  0.030459
# 2  1.010306 -156.753059  0.15  0.030459
# 3  1.008611 -156.807492  0.15  0.030459
# 4  1.010021 -156.761493  0.15  0.030459

# %%
net.res_bus.loc[ net.res_bus.vm_pu > 1.02 ]
# Out:
#         vm_pu   va_degree  p_mw    q_mvar
# 6    1.023551 -155.478506   0.3  0.060918
# 29   1.023672 -155.529761   0.0  0.000000
# 30   1.021042 -155.836976   0.0  0.000000
# 126  1.025896 -155.273690   0.0  0.000000
# 319  1.028804 -154.943953   0.0  0.000000

# %%
net.res_line.loc[ net.res_line.loading_percent > 50. ]
# Out:
#      p_from_mw  q_from_mvar    p_to_mw  q_to_mvar     pl_mw   ql_mvar  \
# 27   -6.597881    -0.537311   6.606828   0.525385  0.008948 -0.011925
# 36   -7.635327    -0.691719   7.640443   0.684674  0.005116 -0.007046
# 38  -12.330775    -1.483886  12.362572   1.568526  0.031798  0.084640
# 39    7.102491     0.822561  -7.097633  -0.827524  0.004857 -0.004962
# 54    7.803244     0.698553  -7.790443  -0.715132  0.012800 -0.016579
# 127 -12.512577    -1.582248  12.585890   1.777424  0.073313  0.195176
# 136   6.857633     0.778790  -6.850680  -0.786739  0.006953 -0.007950
# 137  -6.300425    -0.711482   6.304776   0.705088  0.004351 -0.006394
# 138  -6.694779    -0.773874   6.700678   0.766658  0.005899 -0.007217
# 161   7.587264     1.017911  -7.579017  -1.028473  0.008247 -0.010562
# 172   7.894113     1.040353  -7.889053  -1.045856  0.005059 -0.005503
# 173   7.361037     0.948284  -7.357755  -0.952827  0.003282 -0.004544
# ...
